# %% [markdown]
# # Environment & Config Check

# %%
import sys
print("Python Version:", sys.version)
print("Interpreter Path:", sys.executable)
# Out:
# Python Version: 3.10.20 (main, Jun 11 2026, 15:14:28) [Clang 20.1.8 ]
# Interpreter Path: /Users/croclizh/miniconda3/envs/bootcamp_env/bin/python

# %%
import os
from dotenv import load_dotenv
load_dotenv()
print("API_KEY present:", os.getenv("API_KEY") is not None)
print("DATA_DIR:", os.getenv("DATA_DIR"))
# Out:
# API_KEY present: True
# DATA_DIR: ./data

# %%
import numpy as np
arr = np.array([2, 4, 6, 8, 10])
print("NumPy Array:", arr)
print("Mean:", arr.mean())
# Out:
# NumPy Array: [ 2  4  6  8 10]
# Mean: 6.0
