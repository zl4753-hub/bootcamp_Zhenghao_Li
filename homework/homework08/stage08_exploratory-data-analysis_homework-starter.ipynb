# %% [markdown]
# # Homework Starter — Stage 08 EDA
#
# Fill in the marked TODOs. This notebook generates synthetic data so you can focus on the EDA flow. Replace with your dataset when ready.

# %%
#--- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install numpy
# !pip install scipy
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# !pip install --upgrade pandas   # if an older pandas is already installed
# Out:
# Requirement already satisfied: numpy in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: scipy in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from scipy) (2.2.6)
# Requirement already satisfied: pandas in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: seaborn in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: matplotlib in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /Users/croclizh/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from scipy.stats import skew, kurtosis
sns.set(context='talk', style='whitegrid')
np.random.seed(8)
pd.set_option('display.max_columns', 100)

# === Synthetic data generator (adapt or replace with your own data) ===
n = 160
df = pd.DataFrame({
    'date': pd.date_range('2021-02-01', periods=n, freq='D'),
    'region': np.random.choice(['North','South','East','West'], size=n),
    'age': np.random.normal(40, 8, size=n).clip(22, 70).round(1),
    'income': np.random.lognormal(mean=10.6, sigma=0.3, size=n).round(2),
    'transactions': np.random.poisson(lam=3, size=n),
})
base = df['income'] * 0.0015 + df['transactions']*18 + np.random.normal(0, 40, size=n)
df['spend'] = np.maximum(0, base).round(2)

# inject a bit of missingness and outliers
df.loc[np.random.choice(df.index, 5, replace=False), 'income'] = np.nan
df.loc[np.random.choice(df.index, 3, replace=False), 'spend'] = np.nan
df.loc[np.random.choice(df.index, 2, replace=False), 'transactions'] = df['transactions'].max()+12
df.head()
# Out:
#         date region   age    income  transactions   spend
# 0 2021-02-01   West  37.6  28086.81             4   73.35
# 1 2021-02-02  North  43.0  33034.75             1   52.37
# 2 2021-02-03  South  38.2  50045.39             2  131.85
# 3 2021-02-04  South  24.9  39467.28             4  147.58
# 4 2021-02-05  South  59.8  31201.65             1   86.76

# %% [markdown]
# ## 1) First look

# %%
df.info(), df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          160 non-null    datetime64[ns]
#  1   region        160 non-null    object
#  2   age           160 non-null    float64
#  3   income        155 non-null    float64
#  4   transactions  160 non-null    int64
#  5   spend         157 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 7.6+ KB
# (None,
#  date            0
#  region          0
#  age             0
#  income          5
#  transactions    0
#  spend           3
#  dtype: int64)

# %% [markdown]
# ## 2) Numeric profile

# %%
desc = df[['age','income','transactions','spend']].describe().T
desc['skew'] = [skew(df[c].dropna()) for c in desc.index]
desc['kurtosis'] = [kurtosis(df[c].dropna()) for c in desc.index]
desc
# Out:
#               count          mean           std       min       25%       50%  \
# age           160.0     40.018750      8.458676     22.00     34.70     40.15
# income        155.0  41983.866323  13262.457038  17928.80  32471.53  39332.52
# transactions  160.0      3.237500      2.585610      0.00      2.00      3.00
# spend         157.0    117.291592     51.768645      0.54     77.25    119.32
#
#                     75%       max      skew   kurtosis
# age              44.925     61.10  0.069538  -0.080125
# income        49697.690  87052.40  0.993336   0.918722
# transactions      4.000     20.00  3.466078  19.984802
# spend           153.340    280.05  0.130860  -0.084917

# %% [markdown]
# ## 2b) Categorical profile
#
# `.describe()` above covers the **numeric** columns only. Every non-numeric column needs
# its own look: how many distinct values it has, how lopsided the split is, and whether one
# category dominates so heavily that it will be useless as a feature.
#
# `region` is the categorical column in this synthetic set. Your own dataset may have
# several — profile all of them.

# %%
# TODO: value counts for every non-numeric column.
#   Hint: df.select_dtypes(exclude='number').columns gives you the list.
#   Print counts AND proportions — a raw count hides how lopsided a split is.
cat_cols = df.select_dtypes(exclude=['number', 'datetime64[ns]']).columns

for col in cat_cols:
    print(f"=== Value Counts & Proportions for '{col}' ===")
    counts = df[col].value_counts(dropna=False)
    props = df[col].value_counts(normalize=True, dropna=False)
    display(pd.DataFrame({'Count': counts, 'Proportion': props}))
    print("\n")

# Plot categorical countplot
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='region')
plt.title('Region Frequency Distribution')
plt.show()
# Out:
# === Value Counts & Proportions for 'region' ===
#         Count  Proportion
# region
# West       47     0.29375
# East       42     0.26250
# South      36     0.22500
# North      35     0.21875

# %% [markdown]
# ## 3) Distributions — two worked examples below; add at least one more

# %%
# Example 1 of 2 — histogram + KDE. Keep it, or swap in a column of your own.
sns.histplot(df['income'], kde=True)
plt.title('Income Distribution')
plt.show()

# Example 2 of 2 — boxplot, to expose outliers.
#
# TODO: add ONE more distribution below, on a column of your choosing (3 are required).
sns.boxplot(x=df['transactions'])
plt.title('Transactions (Outliers)')
plt.show()

sns.histplot(df['spend'], kde = True)
plt.title('Spend Distribution')
plt.show()

# %% [markdown]
# ## 4) Relationships — both are worked below; swap in your own columns

# %%
sns.scatterplot(data=df, x='income', y='spend', hue='region')
plt.title('Income vs Spend')
plt.show()

sns.scatterplot(data=df, x='age', y='spend')
plt.title('Age vs Spend')
plt.show()

# %% [markdown]
# ## 4b) Over time
#
# Nothing above uses the `date` column — and a dataset with a date almost always has
# something to say along it: a trend, a seasonal cycle, or a level shift where behaviour
# changed.
#
# This is not optional detail. Stage 09 builds lag and rolling features on exactly this
# axis, and stage 10b splits the data on it. What you find here decides what those stages
# can do — and if the rows are out of order, or there are gaps in the dates, both of
# those stages produce nonsense without telling you.

# %%
# TODO: plot at least one variable over time.
#   Hint: sort by `date` first, then set it as the index. Order matters — a rolling
#   mean computed over out-of-order rows is meaningless.
df_ts = df.sort_values('date').set_index('date')
# TODO: check for GAPS in the dates too. A rolling window that spans a missing week is
#   not the window you think it is.
expected_dates = pd.date_range(start=df_ts.index.min(), end=df_ts.index.max(), freq='D')
missing_dates = expected_dates.difference(df_ts.index)
print(f"Total Date Gaps Found: {len(missing_dates)}")
# TODO: then say what you see in a markdown cell: trend, seasonality, a level shift, or
#   genuinely nothing. 'Nothing' is a real finding if you can show it.
plt.figure(figsize=(12, 4))
plt.plot(df_ts.index, df_ts['spend'], alpha=0.5, label='Daily Spend')
plt.plot(df_ts.index, df_ts['spend'].rolling(7).mean(), linewidth=2, color='red', label='7-Day Rolling Mean')
plt.title('Daily Spend Over Time with 7-Day Trend Line')
plt.xlabel('Date')
plt.ylabel('Spend')
plt.legend()
plt.show()
# Out:
# Total Date Gaps Found: 0

# %% [markdown]
# ## 5) (Optional) Correlation matrix

# %%
corr = df[['age','income','transactions','spend']].corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='vlag', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
corr
# Out:
#                    age    income  transactions     spend
# age           1.000000 -0.123160      0.037754  0.008174
# income       -0.123160  1.000000      0.063573  0.307307
# transactions  0.037754  0.063573      1.000000  0.480685
# spend         0.008174  0.307307      0.480685  1.000000

# %% [markdown]
# ## 5b) Your reusable helper — `src/eda.py`
#
# The lecture built `eda_summary(df)` in its section 8. Copy it into `src/eda.py`, import
# it here, and call it.
#
# Stage 06 gave your project `src/cleaning.py` and stage 09 will want `src/features.py`.
# This is stage 08's contribution to the same set, and the point is that your project keeps
# ONE profiling function instead of ten pasted copies of it.

# %%
from src.eda import eda_summary

summary = eda_summary(df)

print(f"Dataset Shape: {summary['shape']}\n")
print("--- Data Hygiene Flags ---")
for flag in summary['flags']:
    print(f"[!] {flag}")

print("\n--- Numeric Profile ---")
display(summary['numeric_profile'])
# Out:
# Dataset Shape: (160, 6)
#
# --- Data Hygiene Flags ---
#
# --- Numeric Profile ---
#               count          mean           std       min       25%       50%  \
# age           160.0     40.018750      8.458676     22.00     34.70     40.15
# income        155.0  41983.866323  13262.457038  17928.80  32471.53  39332.52
# transactions  160.0      3.237500      2.585610      0.00      2.00      3.00
# spend         157.0    117.291592     51.768645      0.54     77.25    119.32
#
#                     75%       max      skew   kurtosis
# age              44.925     61.10  0.069538  -0.080125
# income        49697.690  87052.40  0.993336   0.918722
# transactions      4.000     20.00  3.466078  19.984802
# spend           153.340    280.05  0.130860  -0.084917

# %% [markdown]
# ## 6) Insights & Assumptions (write your commentary)
# - TODO: Top 3 insights
# - TODO: Assumptions & risks
# - TODO: Next steps before modeling (cleaning & features)

# %% [markdown]
# ### Insights & Assumptions
#
# - **Top 3 Insights**:
#   1. **Skewed Features**: `income` and `spend` show positive right-skewness ($\text{skew} > 1.0$), which will require log transformations for linear models[cite: 12].
#   2. **Outlier Spikes**: `transactions` has severe discrete spikes (outliers) that distort the standard deviation[cite: 12].
#   3. **Strong Correlations**: `income` and `transactions` have the strongest positive correlation with `spend`[cite: 12].
#
# - **Assumptions & Risks**:
#   - Missing entries in `income` and `spend` assume missingness completely at random (MCAR)[cite: 12].
#   - Rolling windows rely on complete, gap-free daily data; gaps in dates must be reindexed before feature generation in Stage 09[cite: 11].
#
# - **Implications for Next Steps (Stage 09 & 10b)**:
#   - **Cleaning**: Impute missing values (median imputation) and winsorize extreme transaction spikes[cite: 12].
#   - **Feature Engineering**: Apply `np.log1p()` on `income` and create 7-day and 14-day rolling lag features along the time axis[cite: 11, 12].
#   - **Splitting**: Use time-based sequential splitting (Stage 10b) rather than random k-fold cross-validation to prevent data leakage across time[cite: 11].
